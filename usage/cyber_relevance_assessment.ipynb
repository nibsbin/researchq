# %% [markdown]
# # ministry Ministry Cybersecurity Assessment
#
# This notebook uses the `cyber_relevance_assessment.py` script to automatically assess whether ministries across different countries are direct stakeholders in their country's cybersecurity ecosystem.
#
# ## Dataset
# - **Source**: `ministries_of_ministry_done_with_all_countries.xlsx`
# - **Domain**: Ministries/departments
# - **Countries**: 193 countries with ministry ministry data
#
# ## Assessment Goal
# Determine if each country's ministry ministry is:
# - **High relevance**: Directly responsible for cybersecurity in ministry sector
# - **Medium relevance**: Some cybersecurity involvement/coordination role
# - **Low relevance**: Minimal cybersecurity involvement
# - **No relevance**: No cybersecurity responsibilities

# %%
# Import required libraries
import pandas as pd
import asyncio
from pathlib import Path
import sys
import os

# Import the cyber relevance assessment functions
from cyber_relevance_assessment import (
    CyberStakeholderAssessment,
    CyberRelevanceLevel,
    ConfidenceLevel,
    load_country_data,
    run_cyber_assessment,
    process_results,
    save_results,
    display_sample_results
)

# Configuration: Set to True for quick testing (5 countries), False for full assessment (all countries)
TEST_MODE = False

print("✅ Successfully imported cyber relevance assessment tools")
print(f"📋 Configuration: {'TEST MODE (5 countries)' if TEST_MODE else 'FULL ASSESSMENT MODE (all countries)'}")
# Out:
# ✅ Successfully imported cyber relevance assessment tools
# 📋 Configuration: FULL ASSESSMENT MODE (all countries)

# %%
# Load and explore the  ministry dataset
data_file = '../data/ministries_of_transportation_done_with_all_countries.xlsx'
domain = 'transportation'
ministry_data = pd.read_excel(data_file)

print(f"Dataset shape: {ministry_data.shape}")
print(f"Columns: {list(ministry_data.columns)}")
print(f"\nUnique countries: {ministry_data['COUNTRY'].nunique()}")
print(f"Total records: {len(ministry_data)}")

# Show sample data
print("\nSample data:")
ministry_data[['COUNTRY']].head(10)
# Out:
# Dataset shape: (193, 32)
# Columns: ['SCOID', 'ISO3', 'COUNTRY', 'ORGANIZATION', 'POSITION', 'MINISTRY_OF_TRANSPORTATION', 'EXISTING', 'INTEL_ORG', 'MIL_ORG', 'CIL_ORG', 'POLICY_ORG', 'TECHNICAL_ORG', 'INTERNAL/EXTERNAL', 'CYB_CRIME', 'CIP', 'TERRORISM', 'E-GOVERNANCE', 'ORGANIZATION_NAME', 'ORG_NAME_NATIVE', 'IN_PROCESS', 'MONTH_CR', 'YEAR_CR', 'MONTH_OPERATIONAL', 'YEAR_OPERATIONAL', 'YEAR_TERMINATED', 'REPLACED_BY (AS OF 2025)', 'PARENT_ORG', 'CODER 1', 'CODER 2', 'CODER 3', 'CODER 4', 'CODER 5']
#
# Unique countries: 193
# Total records: 193
#
# Sample data:
#                COUNTRY
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3              Andorra
# 4               Angola
# 5  Antigua and Barbuda
# 6            Argentina
# 7              Armenia
# 8            Australia
# 9              Austria

# %%
# Extract unique countries for assessment
countries = ministry_data['COUNTRY'].unique().tolist()
print(f"Countries to assess: {len(countries)}")
print(f"First 10 countries: {countries[:10]}")
print(f"Last 10 countries: {countries[-10:]}")
# Out:
# Countries to assess: 193
# First 10 countries: ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria']
# Last 10 countries: ['United Republic of Tanzania', 'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, Bolivarian Republic of', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe']

# %%
# Run cybersecurity assessment based on TEST_MODE configuration
if TEST_MODE:
    # Test mode: run on first 2 countries only
    assessment_countries = countries[:5]
    max_queries = 3
    filename_suffix = "test"
    print(f"🧪 TEST MODE: Running assessment on {len(assessment_countries)} countries: {assessment_countries}")
else:
    # Full mode: run on all countries
    assessment_countries = countries
    max_queries = None
    filename_suffix = "full_assessment"
    print(f"🚀 FULL MODE: Running assessment on {len(assessment_countries)} countries...")
    print("This will take approximately 3-4 minutes...")

# Run the assessment
# Now with true concurrency - max_concurrent > 1 will process queries in parallel
results = await run_cyber_assessment(
    domain=domain,
    countries=assessment_countries,
    max_queries=max_queries,
    delay_seconds=0.5,  # Shorter delay for concurrent processing
    max_concurrent=1    # Process up to 3 queries simultaneously
)

print(f"\n✅ Assessment completed! Generated {len(results)} assessments")
# Out:
# 🚀 FULL MODE: Running assessment on 193 countries...
# This will take approximately 3-4 minutes...
# Starting cybersecurity stakeholder assessment for transportation ministry...
# Assessing 193 countries
# Creating spray with 193 word combinations and 1 research questions...
# Total API calls to make: 193
# Execution mode: sequential (max_concurrent=1)
#
# Processing query 1/193: {'domain': 'transportation', 'country': 'Afghanistan'}
#   Query 1/193: Is the department/ministry of transportation in Afghanistan a direct stakeholder...
#     ✓ Got structured response (1165 chars, 0 retries)
#
# Processing query 2/193: {'domain': 'transportation', 'country': 'Albania'}
#   Query 2/193: Is the department/ministry of transportation in Albania a direct stakeholder (i....
#     ✓ Got structured response (1644 chars, 0 retries)
#
# Processing query 3/193: {'domain': 'transportation', 'country': 'Algeria'}
#   Query 3/193: Is the department/ministry of transportation in Algeria a direct stakeholder (i....
#     ✓ Got structured response (962 chars, 0 retries)
#
# Processing query 4/193: {'domain': 'transportation', 'country': 'Andorra'}
#   Query 4/193: Is the department/ministry of transportation in Andorra a direct stakeholder (i....
#     ✓ Got structured response (1286 chars, 0 retries)
#
# Processing query 5/193: {'domain': 'transportation', 'country': 'Angola'}
#   Query 5/193: Is the department/ministry of transportation in Angola a direct stakeholder (i.e...
#     ✓ Got structured response (1825 chars, 0 retries)
#
# Processing query 6/193: {'domain': 'transportation', 'country': 'Antigua and Barbuda'}
#   Query 6/193: Is the department/ministry of transportation in Antigua and Barbuda a direct sta...
#     ✓ Got structured response (760 chars, 0 retries)
#
# Processing query 7/193: {'domain': 'transportation', 'country': 'Argentina'}
#   Query 7/193: Is the department/ministry of transportation in Argentina a direct stakeholder (...
#     ✓ Got structured response (1102 chars, 0 retries)
#
# Processing query 8/193: {'domain': 'transportation', 'country': 'Armenia'}
#   Query 8/193: Is the department/ministry of transportation in Armenia a direct stakeholder (i....
#     ✓ Got structured response (1417 chars, 0 retries)
#
# Processing query 9/193: {'domain': 'transportation', 'country': 'Australia'}
#   Query 9/193: Is the department/ministry of transportation in Australia a direct stakeholder (...
#     ✓ Got structured response (1572 chars, 0 retries)
#
# Processing query 10/193: {'domain': 'transportation', 'country': 'Austria'}
#   Query 10/193: Is the department/ministry of transportation in Austria a direct stakeholder (i....
#     ✓ Got structured response (1602 chars, 0 retries)
#
# Processing query 11/193: {'domain': 'transportation', 'country': 'Azerbaijan'}
#   Query 11/193: Is the department/ministry of transportation in Azerbaijan a direct stakeholder ...
#     ✓ Got structured response (1096 chars, 0 retries)
#
# Processing query 12/193: {'domain': 'transportation', 'country': 'Bahamas (The)'}
#   Query 12/193: Is the department/ministry of transportation in Bahamas (The) a direct stakehold...
#     ✓ Got structured response (944 chars, 0 retries)
#
# Processing query 13/193: {'domain': 'transportation', 'country': 'Bahrain'}
#   Query 13/193: Is the department/ministry of transportation in Bahrain a direct stakeholder (i....
#     ✓ Got structured response (1234 chars, 0 retries)
#
# Processing query 14/193: {'domain': 'transportation', 'country': 'Bangladesh'}
#   Query 14/193: Is the department/ministry of transportation in Bangladesh a direct stakeholder ...
#     ✓ Got structured response (1253 chars, 0 retries)
#
# Processing query 15/193: {'domain': 'transportation', 'country': 'Barbados'}
#   Query 15/193: Is the department/ministry of transportation in Barbados a direct stakeholder (i...
#     ✓ Got structured response (1136 chars, 0 retries)
#
# Processing query 16/193: {'domain': 'transportation', 'country': 'Belarus'}
#   Query 16/193: Is the department/ministry of transportation in Belarus a direct stakeholder (i....
#     ✓ Got structured response (1510 chars, 0 retries)
#
# Processing query 17/193: {'domain': 'transportation', 'country': 'Belgium'}
#   Query 17/193: Is the department/ministry of transportation in Belgium a direct stakeholder (i....
#     ✓ Got structured response (904 chars, 0 retries)
#
# Processing query 18/193: {'domain': 'transportation', 'country': 'Belize'}
#   Query 18/193: Is the department/ministry of transportation in Belize a direct stakeholder (i.e...
#     ✓ Got structured response (1296 chars, 0 retries)
#
# Processing query 19/193: {'domain': 'transportation', 'country': 'Benin'}
#   Query 19/193: Is the department/ministry of transportation in Benin a direct stakeholder (i.e....
#     ✓ Got structured response (1192 chars, 0 retries)
#
# Processing query 20/193: {'domain': 'transportation', 'country': 'Bhutan'}
#   Query 20/193: Is the department/ministry of transportation in Bhutan a direct stakeholder (i.e...
#     ✓ Got structured response (891 chars, 0 retries)
#
# Processing query 21/193: {'domain': 'transportation', 'country': 'Bolivia (Plurinational State of)'}
#   Query 21/193: Is the department/ministry of transportation in Bolivia (Plurinational State of)...
#     ✓ Got structured response (894 chars, 0 retries)
#
# Processing query 22/193: {'domain': 'transportation', 'country': 'Bosnia and Herzegovina'}
#   Query 22/193: Is the department/ministry of transportation in Bosnia and Herzegovina a direct ...
#     ✓ Got structured response (1231 chars, 0 retries)
#
# Processing query 23/193: {'domain': 'transportation', 'country': 'Botswana'}
#   Query 23/193: Is the department/ministry of transportation in Botswana a direct stakeholder (i...
#     ✓ Got structured response (755 chars, 0 retries)
#
# Processing query 24/193: {'domain': 'transportation', 'country': 'Brazil'}
#   Query 24/193: Is the department/ministry of transportation in Brazil a direct stakeholder (i.e...
#     ✓ Got structured response (1291 chars, 0 retries)
#
# Processing query 25/193: {'domain': 'transportation', 'country': 'Brunei Darussalam'}
#   Query 25/193: Is the department/ministry of transportation in Brunei Darussalam a direct stake...
#     ✓ Got structured response (999 chars, 0 retries)
#
# Processing query 26/193: {'domain': 'transportation', 'country': 'Bulgaria'}
#   Query 26/193: Is the department/ministry of transportation in Bulgaria a direct stakeholder (i...
#     ✓ Got structured response (1202 chars, 0 retries)
#
# Processing query 27/193: {'domain': 'transportation', 'country': 'Burkina Faso'}
#   Query 27/193: Is the department/ministry of transportation in Burkina Faso a direct stakeholde...
#     ✓ Got structured response (814 chars, 0 retries)
#
# Processing query 28/193: {'domain': 'transportation', 'country': 'Burundi'}
#   Query 28/193: Is the department/ministry of transportation in Burundi a direct stakeholder (i....
#     ✓ Got structured response (874 chars, 0 retries)
#
# Processing query 29/193: {'domain': 'transportation', 'country': 'Cabo Verde'}
#   Query 29/193: Is the department/ministry of transportation in Cabo Verde a direct stakeholder ...
#     ✓ Got structured response (1210 chars, 0 retries)
#
# Processing query 30/193: {'domain': 'transportation', 'country': 'Cambodia'}
#   Query 30/193: Is the department/ministry of transportation in Cambodia a direct stakeholder (i...
#     ✓ Got structured response (1226 chars, 0 retries)
#
# Processing query 31/193: {'domain': 'transportation', 'country': 'Cameroon'}
#   Query 31/193: Is the department/ministry of transportation in Cameroon a direct stakeholder (i...
#     ✓ Got structured response (908 chars, 0 retries)
#
# Processing query 32/193: {'domain': 'transportation', 'country': 'Canada'}
#   Query 32/193: Is the department/ministry of transportation in Canada a direct stakeholder (i.e...
#     ✓ Got structured response (1465 chars, 0 retries)
#
# Processing query 33/193: {'domain': 'transportation', 'country': 'Central African Republic'}
#   Query 33/193: Is the department/ministry of transportation in Central African Republic a direc...
#     ✓ Got structured response (1040 chars, 0 retries)
#
# Processing query 34/193: {'domain': 'transportation', 'country': 'Chad'}
#   Query 34/193: Is the department/ministry of transportation in Chad a direct stakeholder (i.e.,...
#     ✓ Got structured response (824 chars, 0 retries)
#
# Processing query 35/193: {'domain': 'transportation', 'country': 'Chile'}
#   Query 35/193: Is the department/ministry of transportation in Chile a direct stakeholder (i.e....
#     ✓ Got structured response (1077 chars, 0 retries)
#
# Processing query 36/193: {'domain': 'transportation', 'country': 'China'}
#   Query 36/193: Is the department/ministry of transportation in China a direct stakeholder (i.e....
#     ✓ Got structured response (1476 chars, 0 retries)
#
# Processing query 37/193: {'domain': 'transportation', 'country': 'Colombia'}
#   Query 37/193: Is the department/ministry of transportation in Colombia a direct stakeholder (i...
#     ✓ Got structured response (1069 chars, 0 retries)
#
# Processing query 38/193: {'domain': 'transportation', 'country': 'Comoros'}
#   Query 38/193: Is the department/ministry of transportation in Comoros a direct stakeholder (i....
#     ✓ Got structured response (1127 chars, 0 retries)
#
# Processing query 39/193: {'domain': 'transportation', 'country': 'Congo'}
#   Query 39/193: Is the department/ministry of transportation in Congo a direct stakeholder (i.e....
#     ✓ Got structured response (1356 chars, 0 retries)
#
# Processing query 40/193: {'domain': 'transportation', 'country': 'Costa Rica'}
#   Query 40/193: Is the department/ministry of transportation in Costa Rica a direct stakeholder ...
#     ✓ Got structured response (1222 chars, 0 retries)
#
# Processing query 41/193: {'domain': 'transportation', 'country': 'Côte d’Ivoire'}
#   Query 41/193: Is the department/ministry of transportation in Côte d’Ivoire a direct stakehold...
#     ✓ Got structured response (1014 chars, 0 retries)
#
# Processing query 42/193: {'domain': 'transportation', 'country': 'Croatia'}
#   Query 42/193: Is the department/ministry of transportation in Croatia a direct stakeholder (i....
#     ✓ Got structured response (1070 chars, 0 retries)
#
# Processing query 43/193: {'domain': 'transportation', 'country': 'Cuba'}
#   Query 43/193: Is the department/ministry of transportation in Cuba a direct stakeholder (i.e.,...
#     ✓ Got structured response (1201 chars, 0 retries)
#
# Processing query 44/193: {'domain': 'transportation', 'country': 'Cyprus'}
#   Query 44/193: Is the department/ministry of transportation in Cyprus a direct stakeholder (i.e...
#     ✓ Got structured response (1101 chars, 0 retries)
#
# Processing query 45/193: {'domain': 'transportation', 'country': 'Czechia'}
#   Query 45/193: Is the department/ministry of transportation in Czechia a direct stakeholder (i....
#     ✓ Got structured response (1088 chars, 0 retries)
#
# Processing query 46/193: {'domain': 'transportation', 'country': "Democratic People's Republic of Korea"}
#   Query 46/193: Is the department/ministry of transportation in Democratic People's Republic of ...
#     ✓ Got structured response (883 chars, 0 retries)
#
# Processing query 47/193: {'domain': 'transportation', 'country': 'Democratic Republic of the Congo'}
#   Query 47/193: Is the department/ministry of transportation in Democratic Republic of the Congo...
#     ✓ Got structured response (1095 chars, 0 retries)
#
# Processing query 48/193: {'domain': 'transportation', 'country': 'Denmark'}
#   Query 48/193: Is the department/ministry of transportation in Denmark a direct stakeholder (i....
#     ✓ Got structured response (1091 chars, 0 retries)
#
# Processing query 49/193: {'domain': 'transportation', 'country': 'Djibouti'}
#   Query 49/193: Is the department/ministry of transportation in Djibouti a direct stakeholder (i...
#     ✓ Got structured response (1299 chars, 0 retries)
#
# Processing query 50/193: {'domain': 'transportation', 'country': 'Dominica'}
#   Query 50/193: Is the department/ministry of transportation in Dominica a direct stakeholder (i...
#     ✓ Got structured response (886 chars, 0 retries)
#
# Processing query 51/193: {'domain': 'transportation', 'country': 'Dominican Republic'}
#   Query 51/193: Is the department/ministry of transportation in Dominican Republic a direct stak...
#     ✓ Got structured response (1135 chars, 0 retries)
#
# Processing query 52/193: {'domain': 'transportation', 'country': 'Ecuador'}
#   Query 52/193: Is the department/ministry of transportation in Ecuador a direct stakeholder (i....
#     ✓ Got structured response (916 chars, 0 retries)
#
# Processing query 53/193: {'domain': 'transportation', 'country': 'Egypt'}
#   Query 53/193: Is the department/ministry of transportation in Egypt a direct stakeholder (i.e....
#     ✓ Got structured response (1792 chars, 0 retries)
#
# Processing query 54/193: {'domain': 'transportation', 'country': 'El Salvador'}
#   Query 54/193: Is the department/ministry of transportation in El Salvador a direct stakeholder...
#     ✓ Got structured response (1598 chars, 0 retries)
#
# Processing query 55/193: {'domain': 'transportation', 'country': 'Equatorial Guinea'}
#   Query 55/193: Is the department/ministry of transportation in Equatorial Guinea a direct stake...
#     ✓ Got structured response (899 chars, 0 retries)
#
# Processing query 56/193: {'domain': 'transportation', 'country': 'Eritrea'}
#   Query 56/193: Is the department/ministry of transportation in Eritrea a direct stakeholder (i....
#     ✓ Got structured response (1005 chars, 0 retries)
#
# Processing query 57/193: {'domain': 'transportation', 'country': 'Estonia'}
#   Query 57/193: Is the department/ministry of transportation in Estonia a direct stakeholder (i....
#     ✓ Got structured response (997 chars, 0 retries)
#
# Processing query 58/193: {'domain': 'transportation', 'country': 'Eswatini'}
#   Query 58/193: Is the department/ministry of transportation in Eswatini a direct stakeholder (i...
#     ✓ Got structured response (1103 chars, 0 retries)
#
# Processing query 59/193: {'domain': 'transportation', 'country': 'Ethiopia'}
#   Query 59/193: Is the department/ministry of transportation in Ethiopia a direct stakeholder (i...
#     ✓ Got structured response (1561 chars, 0 retries)
#
# Processing query 60/193: {'domain': 'transportation', 'country': 'Fiji'}
#   Query 60/193: Is the department/ministry of transportation in Fiji a direct stakeholder (i.e.,...
#     ✓ Got structured response (1415 chars, 0 retries)
#
# Processing query 61/193: {'domain': 'transportation', 'country': 'Finland'}
#   Query 61/193: Is the department/ministry of transportation in Finland a direct stakeholder (i....
#     ✓ Got structured response (1101 chars, 0 retries)
#
# Processing query 62/193: {'domain': 'transportation', 'country': 'France'}
#   Query 62/193: Is the department/ministry of transportation in France a direct stakeholder (i.e...
#     ✓ Got structured response (1435 chars, 0 retries)
#
# Processing query 63/193: {'domain': 'transportation', 'country': 'Gabon'}
#   Query 63/193: Is the department/ministry of transportation in Gabon a direct stakeholder (i.e....
#     ✓ Got structured response (967 chars, 0 retries)
#
# Processing query 64/193: {'domain': 'transportation', 'country': 'Gambia (Republic of The)'}
#   Query 64/193: Is the department/ministry of transportation in Gambia (Republic of The) a direc...
#     ✓ Got structured response (1227 chars, 0 retries)
#
# Processing query 65/193: {'domain': 'transportation', 'country': 'Georgia'}
#   Query 65/193: Is the department/ministry of transportation in Georgia a direct stakeholder (i....
#     ✓ Got structured response (710 chars, 0 retries)
#
# Processing query 66/193: {'domain': 'transportation', 'country': 'Germany'}
#   Query 66/193: Is the department/ministry of transportation in Germany a direct stakeholder (i....
#     ✓ Got structured response (1604 chars, 0 retries)
#
# Processing query 67/193: {'domain': 'transportation', 'country': 'Ghana'}
#   Query 67/193: Is the department/ministry of transportation in Ghana a direct stakeholder (i.e....
#     ✓ Got structured response (1399 chars, 0 retries)
#
# Processing query 68/193: {'domain': 'transportation', 'country': 'Greece'}
#   Query 68/193: Is the department/ministry of transportation in Greece a direct stakeholder (i.e...
#     ✓ Got structured response (1122 chars, 0 retries)
#
# Processing query 69/193: {'domain': 'transportation', 'country': 'Grenada'}
#   Query 69/193: Is the department/ministry of transportation in Grenada a direct stakeholder (i....
#     ✓ Got structured response (874 chars, 0 retries)
#
# Processing query 70/193: {'domain': 'transportation', 'country': 'Guatemala'}
#   Query 70/193: Is the department/ministry of transportation in Guatemala a direct stakeholder (...
#     ✓ Got structured response (1010 chars, 0 retries)
#
# Processing query 71/193: {'domain': 'transportation', 'country': 'Guinea'}
#   Query 71/193: Is the department/ministry of transportation in Guinea a direct stakeholder (i.e...
#     ✓ Got structured response (1514 chars, 0 retries)
#
# Processing query 72/193: {'domain': 'transportation', 'country': 'Guinea-Bissau'}
#   Query 72/193: Is the department/ministry of transportation in Guinea-Bissau a direct stakehold...
#     ✓ Got structured response (1065 chars, 0 retries)
#
# Processing query 73/193: {'domain': 'transportation', 'country': 'Guyana'}
#   Query 73/193: Is the department/ministry of transportation in Guyana a direct stakeholder (i.e...
#     ✓ Got structured response (1250 chars, 0 retries)
#
# Processing query 74/193: {'domain': 'transportation', 'country': 'Haiti'}
#   Query 74/193: Is the department/ministry of transportation in Haiti a direct stakeholder (i.e....
#     ✓ Got structured response (1342 chars, 0 retries)
#
# Processing query 75/193: {'domain': 'transportation', 'country': 'Honduras'}
#   Query 75/193: Is the department/ministry of transportation in Honduras a direct stakeholder (i...
#     ✓ Got structured response (956 chars, 0 retries)
#
# Processing query 76/193: {'domain': 'transportation', 'country': 'Hungary'}
#   Query 76/193: Is the department/ministry of transportation in Hungary a direct stakeholder (i....
#     ✓ Got structured response (1564 chars, 0 retries)
#
# Processing query 77/193: {'domain': 'transportation', 'country': 'Iceland'}
#   Query 77/193: Is the department/ministry of transportation in Iceland a direct stakeholder (i....
#     ✓ Got structured response (930 chars, 0 retries)
#
# Processing query 78/193: {'domain': 'transportation', 'country': 'India'}
#   Query 78/193: Is the department/ministry of transportation in India a direct stakeholder (i.e....
#     ✓ Got structured response (915 chars, 0 retries)
#
# Processing query 79/193: {'domain': 'transportation', 'country': 'Indonesia'}
#   Query 79/193: Is the department/ministry of transportation in Indonesia a direct stakeholder (...
#     ✓ Got structured response (1138 chars, 0 retries)
#
# Processing query 80/193: {'domain': 'transportation', 'country': 'Iran (Islamic Republic of)'}
#   Query 80/193: Is the department/ministry of transportation in Iran (Islamic Republic of) a dir...
#     ✓ Got structured response (957 chars, 0 retries)
#
# Processing query 81/193: {'domain': 'transportation', 'country': 'Iraq'}
#   Query 81/193: Is the department/ministry of transportation in Iraq a direct stakeholder (i.e.,...
#     ✓ Got structured response (1096 chars, 0 retries)
#
# Processing query 82/193: {'domain': 'transportation', 'country': 'Ireland'}
#   Query 82/193: Is the department/ministry of transportation in Ireland a direct stakeholder (i....
#     ✓ Got structured response (1098 chars, 0 retries)
#
# Processing query 83/193: {'domain': 'transportation', 'country': 'Israel'}
#   Query 83/193: Is the department/ministry of transportation in Israel a direct stakeholder (i.e...
#     ✓ Got structured response (584 chars, 0 retries)
#
# Processing query 84/193: {'domain': 'transportation', 'country': 'Italy'}
#   Query 84/193: Is the department/ministry of transportation in Italy a direct stakeholder (i.e....
#     ✓ Got structured response (1077 chars, 0 retries)
#
# Processing query 85/193: {'domain': 'transportation', 'country': 'Jamaica'}
#   Query 85/193: Is the department/ministry of transportation in Jamaica a direct stakeholder (i....
#     ✓ Got structured response (1230 chars, 0 retries)
#
# Processing query 86/193: {'domain': 'transportation', 'country': 'Japan'}
#   Query 86/193: Is the department/ministry of transportation in Japan a direct stakeholder (i.e....
#     ✓ Got structured response (1554 chars, 0 retries)
#
# Processing query 87/193: {'domain': 'transportation', 'country': 'Jordan'}
#   Query 87/193: Is the department/ministry of transportation in Jordan a direct stakeholder (i.e...
#     ✓ Got structured response (1227 chars, 0 retries)
#
# Processing query 88/193: {'domain': 'transportation', 'country': 'Kazakhstan'}
#   Query 88/193: Is the department/ministry of transportation in Kazakhstan a direct stakeholder ...
#     ✓ Got structured response (962 chars, 0 retries)
#
# Processing query 89/193: {'domain': 'transportation', 'country': 'Kenya'}
#   Query 89/193: Is the department/ministry of transportation in Kenya a direct stakeholder (i.e....
#     ✓ Got structured response (1218 chars, 0 retries)
#
# Processing query 90/193: {'domain': 'transportation', 'country': 'Kiribati'}
#   Query 90/193: Is the department/ministry of transportation in Kiribati a direct stakeholder (i...
#     ✓ Got structured response (1391 chars, 0 retries)
#
# Processing query 91/193: {'domain': 'transportation', 'country': 'Kuwait'}
#   Query 91/193: Is the department/ministry of transportation in Kuwait a direct stakeholder (i.e...
#     ✓ Got structured response (1174 chars, 0 retries)
#
# Processing query 92/193: {'domain': 'transportation', 'country': 'Kyrgyzstan'}
#   Query 92/193: Is the department/ministry of transportation in Kyrgyzstan a direct stakeholder ...
#     ✓ Got structured response (1081 chars, 0 retries)
#
# Processing query 93/193: {'domain': 'transportation', 'country': "Lao People's Democratic Republic"}
#   Query 93/193: Is the department/ministry of transportation in Lao People's Democratic Republic...
#     ✓ Got structured response (632 chars, 0 retries)
#
# Processing query 94/193: {'domain': 'transportation', 'country': 'Latvia'}
#   Query 94/193: Is the department/ministry of transportation in Latvia a direct stakeholder (i.e...
#     ✓ Got structured response (927 chars, 0 retries)
#
# Processing query 95/193: {'domain': 'transportation', 'country': 'Lebanon'}
#   Query 95/193: Is the department/ministry of transportation in Lebanon a direct stakeholder (i....
#     ✓ Got structured response (1150 chars, 0 retries)
#
# Processing query 96/193: {'domain': 'transportation', 'country': 'Lesotho'}
#   Query 96/193: Is the department/ministry of transportation in Lesotho a direct stakeholder (i....
#     ✓ Got structured response (1241 chars, 0 retries)
#
# Processing query 97/193: {'domain': 'transportation', 'country': 'Liberia'}
#   Query 97/193: Is the department/ministry of transportation in Liberia a direct stakeholder (i....
#     ✓ Got structured response (1254 chars, 0 retries)
#
# Processing query 98/193: {'domain': 'transportation', 'country': 'Libya'}
#   Query 98/193: Is the department/ministry of transportation in Libya a direct stakeholder (i.e....
#     ✓ Got structured response (1358 chars, 0 retries)
#
# Processing query 99/193: {'domain': 'transportation', 'country': 'Liechtenstein'}
#   Query 99/193: Is the department/ministry of transportation in Liechtenstein a direct stakehold...
#     ✓ Got structured response (701 chars, 0 retries)
#
# Processing query 100/193: {'domain': 'transportation', 'country': 'Lithuania'}
#   Query 100/193: Is the department/ministry of transportation in Lithuania a direct stakeholder (...
#     ✓ Got structured response (1133 chars, 0 retries)
#
# Processing query 101/193: {'domain': 'transportation', 'country': 'Luxembourg'}
#   Query 101/193: Is the department/ministry of transportation in Luxembourg a direct stakeholder ...
#     ✓ Got structured response (1206 chars, 0 retries)
#
# Processing query 102/193: {'domain': 'transportation', 'country': 'Madagascar'}
#   Query 102/193: Is the department/ministry of transportation in Madagascar a direct stakeholder ...
#     ✓ Got structured response (972 chars, 0 retries)
#
# Processing query 103/193: {'domain': 'transportation', 'country': 'Malawi'}
#   Query 103/193: Is the department/ministry of transportation in Malawi a direct stakeholder (i.e...
#     ✓ Got structured response (1192 chars, 0 retries)
#
# Processing query 104/193: {'domain': 'transportation', 'country': 'Malaysia'}
#   Query 104/193: Is the department/ministry of transportation in Malaysia a direct stakeholder (i...
#     ✓ Got structured response (1593 chars, 0 retries)
#
# Processing query 105/193: {'domain': 'transportation', 'country': 'Maldives'}
#   Query 105/193: Is the department/ministry of transportation in Maldives a direct stakeholder (i...
#     ✓ Got structured response (1062 chars, 0 retries)
#
# Processing query 106/193: {'domain': 'transportation', 'country': 'Mali'}
#   Query 106/193: Is the department/ministry of transportation in Mali a direct stakeholder (i.e.,...
#     ✓ Got structured response (1087 chars, 0 retries)
#
# Processing query 107/193: {'domain': 'transportation', 'country': 'Malta'}
#   Query 107/193: Is the department/ministry of transportation in Malta a direct stakeholder (i.e....
#     ✓ Got structured response (1194 chars, 0 retries)
#
# Processing query 108/193: {'domain': 'transportation', 'country': 'Marshall Islands'}
#   Query 108/193: Is the department/ministry of transportation in Marshall Islands a direct stakeh...
#     ✓ Got structured response (1539 chars, 0 retries)
#
# Processing query 109/193: {'domain': 'transportation', 'country': 'Mauritania'}
#   Query 109/193: Is the department/ministry of transportation in Mauritania a direct stakeholder ...
#     ✓ Got structured response (1401 chars, 0 retries)
#
# Processing query 110/193: {'domain': 'transportation', 'country': 'Mauritius'}
#   Query 110/193: Is the department/ministry of transportation in Mauritius a direct stakeholder (...
#     ✓ Got structured response (1086 chars, 0 retries)
#
# Processing query 111/193: {'domain': 'transportation', 'country': 'Mexico'}
#   Query 111/193: Is the department/ministry of transportation in Mexico a direct stakeholder (i.e...
#     ✓ Got structured response (1395 chars, 0 retries)
#
# Processing query 112/193: {'domain': 'transportation', 'country': 'Micronesia (Federated States of)'}
#   Query 112/193: Is the department/ministry of transportation in Micronesia (Federated States of)...
#     ✓ Got structured response (917 chars, 0 retries)
#
# Processing query 113/193: {'domain': 'transportation', 'country': 'Monaco'}
#   Query 113/193: Is the department/ministry of transportation in Monaco a direct stakeholder (i.e...
#     ✓ Got structured response (1472 chars, 0 retries)
#
# Processing query 114/193: {'domain': 'transportation', 'country': 'Mongolia'}
#   Query 114/193: Is the department/ministry of transportation in Mongolia a direct stakeholder (i...
#     ✓ Got structured response (1085 chars, 0 retries)
#
# Processing query 115/193: {'domain': 'transportation', 'country': 'Montenegro'}
#   Query 115/193: Is the department/ministry of transportation in Montenegro a direct stakeholder ...
#     ✓ Got structured response (1146 chars, 0 retries)
#
# Processing query 116/193: {'domain': 'transportation', 'country': 'Morocco'}
#   Query 116/193: Is the department/ministry of transportation in Morocco a direct stakeholder (i....
#     ✓ Got structured response (1308 chars, 0 retries)
#
# Processing query 117/193: {'domain': 'transportation', 'country': 'Mozambique'}
#   Query 117/193: Is the department/ministry of transportation in Mozambique a direct stakeholder ...
#     ✓ Got structured response (1230 chars, 0 retries)
#
# Processing query 118/193: {'domain': 'transportation', 'country': 'Myanmar'}
#   Query 118/193: Is the department/ministry of transportation in Myanmar a direct stakeholder (i....
#     ✓ Got structured response (1482 chars, 0 retries)
#
# Processing query 119/193: {'domain': 'transportation', 'country': 'Namibia'}
#   Query 119/193: Is the department/ministry of transportation in Namibia a direct stakeholder (i....
#     ✓ Got structured response (1068 chars, 0 retries)
#
# Processing query 120/193: {'domain': 'transportation', 'country': 'Nauru'}
#   Query 120/193: Is the department/ministry of transportation in Nauru a direct stakeholder (i.e....
#     ✓ Got structured response (955 chars, 0 retries)
#
# Processing query 121/193: {'domain': 'transportation', 'country': 'Nepal'}
#   Query 121/193: Is the department/ministry of transportation in Nepal a direct stakeholder (i.e....
#     ✓ Got structured response (952 chars, 0 retries)
#
# Processing query 122/193: {'domain': 'transportation', 'country': 'Netherlands (Kingdom of the)'}
#   Query 122/193: Is the department/ministry of transportation in Netherlands (Kingdom of the) a d...
#     ✓ Got structured response (1458 chars, 0 retries)
#
# Processing query 123/193: {'domain': 'transportation', 'country': 'New Zealand'}
#   Query 123/193: Is the department/ministry of transportation in New Zealand a direct stakeholder...
#     ✓ Got structured response (1255 chars, 0 retries)
#
# Processing query 124/193: {'domain': 'transportation', 'country': 'Nicaragua'}
#   Query 124/193: Is the department/ministry of transportation in Nicaragua a direct stakeholder (...
#     ✓ Got structured response (1350 chars, 0 retries)
#
# Processing query 125/193: {'domain': 'transportation', 'country': 'Niger'}
#   Query 125/193: Is the department/ministry of transportation in Niger a direct stakeholder (i.e....
#     ✓ Got structured response (1133 chars, 0 retries)
#
# Processing query 126/193: {'domain': 'transportation', 'country': 'Nigeria'}
#   Query 126/193: Is the department/ministry of transportation in Nigeria a direct stakeholder (i....
#     ✓ Got structured response (1138 chars, 0 retries)
#
# Processing query 127/193: {'domain': 'transportation', 'country': 'North Macedonia'}
#   Query 127/193: Is the department/ministry of transportation in North Macedonia a direct stakeho...
#     ✓ Got structured response (1437 chars, 0 retries)
#
# Processing query 128/193: {'domain': 'transportation', 'country': 'Norway'}
#   Query 128/193: Is the department/ministry of transportation in Norway a direct stakeholder (i.e...
#     ✓ Got structured response (1147 chars, 0 retries)
#
# Processing query 129/193: {'domain': 'transportation', 'country': 'Oman'}
#   Query 129/193: Is the department/ministry of transportation in Oman a direct stakeholder (i.e.,...
#     ✓ Got structured response (767 chars, 0 retries)
#
# Processing query 130/193: {'domain': 'transportation', 'country': 'Pakistan'}
#   Query 130/193: Is the department/ministry of transportation in Pakistan a direct stakeholder (i...
#     ✓ Got structured response (1440 chars, 0 retries)
#
# Processing query 131/193: {'domain': 'transportation', 'country': 'Palau'}
#   Query 131/193: Is the department/ministry of transportation in Palau a direct stakeholder (i.e....
#     ✓ Got structured response (1081 chars, 0 retries)
#
# Processing query 132/193: {'domain': 'transportation', 'country': 'Panama'}
#   Query 132/193: Is the department/ministry of transportation in Panama a direct stakeholder (i.e...
#     ✓ Got structured response (1369 chars, 0 retries)
#
# Processing query 133/193: {'domain': 'transportation', 'country': 'Papua New Guinea'}
#   Query 133/193: Is the department/ministry of transportation in Papua New Guinea a direct stakeh...
#     ✓ Got structured response (1229 chars, 0 retries)
#
# Processing query 134/193: {'domain': 'transportation', 'country': 'Paraguay'}
#   Query 134/193: Is the department/ministry of transportation in Paraguay a direct stakeholder (i...
#     ✓ Got structured response (996 chars, 0 retries)
#
# Processing query 135/193: {'domain': 'transportation', 'country': 'Peru'}
#   Query 135/193: Is the department/ministry of transportation in Peru a direct stakeholder (i.e.,...
#     ✓ Got structured response (980 chars, 0 retries)
#
# Processing query 136/193: {'domain': 'transportation', 'country': 'Philippines'}
#   Query 136/193: Is the department/ministry of transportation in Philippines a direct stakeholder...
#     ✓ Got structured response (1188 chars, 0 retries)
#
# Processing query 137/193: {'domain': 'transportation', 'country': 'Poland'}
#   Query 137/193: Is the department/ministry of transportation in Poland a direct stakeholder (i.e...
#     ✓ Got structured response (983 chars, 0 retries)
#
# Processing query 138/193: {'domain': 'transportation', 'country': 'Portugal'}
#   Query 138/193: Is the department/ministry of transportation in Portugal a direct stakeholder (i...
#     ✓ Got structured response (1244 chars, 0 retries)
#
# Processing query 139/193: {'domain': 'transportation', 'country': 'Qatar'}
#   Query 139/193: Is the department/ministry of transportation in Qatar a direct stakeholder (i.e....
#     ✓ Got structured response (1161 chars, 0 retries)
#
# Processing query 140/193: {'domain': 'transportation', 'country': 'Republic of Korea'}
#   Query 140/193: Is the department/ministry of transportation in Republic of Korea a direct stake...
#     ✓ Got structured response (1312 chars, 0 retries)
#
# Processing query 141/193: {'domain': 'transportation', 'country': 'Republic of Moldova'}
#   Query 141/193: Is the department/ministry of transportation in Republic of Moldova a direct sta...
#     ✓ Got structured response (1265 chars, 0 retries)
#
# Processing query 142/193: {'domain': 'transportation', 'country': 'Romania'}
#   Query 142/193: Is the department/ministry of transportation in Romania a direct stakeholder (i....
#     ✓ Got structured response (1095 chars, 0 retries)
#
# Processing query 143/193: {'domain': 'transportation', 'country': 'Russian Federation'}
#   Query 143/193: Is the department/ministry of transportation in Russian Federation a direct stak...
#     ✓ Got structured response (1265 chars, 0 retries)
#
# Processing query 144/193: {'domain': 'transportation', 'country': 'Rwanda'}
#   Query 144/193: Is the department/ministry of transportation in Rwanda a direct stakeholder (i.e...
#     ✓ Got structured response (1095 chars, 0 retries)
#
# Processing query 145/193: {'domain': 'transportation', 'country': 'Saint Kitts and Nevis'}
#   Query 145/193: Is the department/ministry of transportation in Saint Kitts and Nevis a direct s...
#     ✓ Got structured response (961 chars, 0 retries)
#
# Processing query 146/193: {'domain': 'transportation', 'country': 'Saint Lucia'}
#   Query 146/193: Is the department/ministry of transportation in Saint Lucia a direct stakeholder...
#     ✓ Got structured response (1275 chars, 0 retries)
#
# Processing query 147/193: {'domain': 'transportation', 'country': 'Saint Vincent and the Grenadines'}
#   Query 147/193: Is the department/ministry of transportation in Saint Vincent and the Grenadines...
#     ✓ Got structured response (809 chars, 0 retries)
#
# Processing query 148/193: {'domain': 'transportation', 'country': 'Samoa'}
#   Query 148/193: Is the department/ministry of transportation in Samoa a direct stakeholder (i.e....
#     ✓ Got structured response (1251 chars, 0 retries)
#
# Processing query 149/193: {'domain': 'transportation', 'country': 'San Marino'}
#   Query 149/193: Is the department/ministry of transportation in San Marino a direct stakeholder ...
#     ✓ Got structured response (873 chars, 0 retries)
#
# Processing query 150/193: {'domain': 'transportation', 'country': 'Sao Tome and Principe'}
#   Query 150/193: Is the department/ministry of transportation in Sao Tome and Principe a direct s...
#     ✓ Got structured response (1221 chars, 0 retries)
#
# Processing query 151/193: {'domain': 'transportation', 'country': 'Saudi Arabia'}
#   Query 151/193: Is the department/ministry of transportation in Saudi Arabia a direct stakeholde...
#     ✓ Got structured response (1939 chars, 0 retries)
#
# Processing query 152/193: {'domain': 'transportation', 'country': 'Senegal'}
#   Query 152/193: Is the department/ministry of transportation in Senegal a direct stakeholder (i....
#     ✓ Got structured response (1055 chars, 0 retries)
#
# Processing query 153/193: {'domain': 'transportation', 'country': 'Serbia'}
#   Query 153/193: Is the department/ministry of transportation in Serbia a direct stakeholder (i.e...
#     ✓ Got structured response (684 chars, 0 retries)
#
# Processing query 154/193: {'domain': 'transportation', 'country': 'Seychelles'}
#   Query 154/193: Is the department/ministry of transportation in Seychelles a direct stakeholder ...
#     ✓ Got structured response (1692 chars, 0 retries)
#
# Processing query 155/193: {'domain': 'transportation', 'country': 'Sierra Leone'}
#   Query 155/193: Is the department/ministry of transportation in Sierra Leone a direct stakeholde...
#     ✓ Got structured response (1119 chars, 0 retries)
#
# Processing query 156/193: {'domain': 'transportation', 'country': 'Singapore'}
#   Query 156/193: Is the department/ministry of transportation in Singapore a direct stakeholder (...
#     ✓ Got structured response (1166 chars, 0 retries)
#
# Processing query 157/193: {'domain': 'transportation', 'country': 'Slovakia'}
#   Query 157/193: Is the department/ministry of transportation in Slovakia a direct stakeholder (i...
#     ✓ Got structured response (1272 chars, 0 retries)
#
# Processing query 158/193: {'domain': 'transportation', 'country': 'Slovenia'}
#   Query 158/193: Is the department/ministry of transportation in Slovenia a direct stakeholder (i...
#     ✓ Got structured response (1331 chars, 0 retries)
#
# Processing query 159/193: {'domain': 'transportation', 'country': 'Solomon Islands'}
#   Query 159/193: Is the department/ministry of transportation in Solomon Islands a direct stakeho...
#     ✓ Got structured response (936 chars, 0 retries)
#
# Processing query 160/193: {'domain': 'transportation', 'country': 'Somalia'}
#   Query 160/193: Is the department/ministry of transportation in Somalia a direct stakeholder (i....
#     ✓ Got structured response (1015 chars, 0 retries)
#
# Processing query 161/193: {'domain': 'transportation', 'country': 'South Africa'}
#   Query 161/193: Is the department/ministry of transportation in South Africa a direct stakeholde...
#     ✓ Got structured response (1229 chars, 0 retries)
#
# Processing query 162/193: {'domain': 'transportation', 'country': 'South Sudan'}
#   Query 162/193: Is the department/ministry of transportation in South Sudan a direct stakeholder...
#     ✓ Got structured response (1313 chars, 0 retries)
#
# Processing query 163/193: {'domain': 'transportation', 'country': 'Spain'}
#   Query 163/193: Is the department/ministry of transportation in Spain a direct stakeholder (i.e....
#     ✓ Got structured response (1279 chars, 0 retries)
#
# Processing query 164/193: {'domain': 'transportation', 'country': 'Sri Lanka'}
#   Query 164/193: Is the department/ministry of transportation in Sri Lanka a direct stakeholder (...
#     ✓ Got structured response (1200 chars, 0 retries)
#
# Processing query 165/193: {'domain': 'transportation', 'country': 'Sudan'}
#   Query 165/193: Is the department/ministry of transportation in Sudan a direct stakeholder (i.e....
#     ✓ Got structured response (1260 chars, 0 retries)
#
# Processing query 166/193: {'domain': 'transportation', 'country': 'Suriname'}
#   Query 166/193: Is the department/ministry of transportation in Suriname a direct stakeholder (i...
#     ✓ Got structured response (1069 chars, 0 retries)
#
# Processing query 167/193: {'domain': 'transportation', 'country': 'Sweden'}
#   Query 167/193: Is the department/ministry of transportation in Sweden a direct stakeholder (i.e...
#     ✓ Got structured response (941 chars, 0 retries)
#
# Processing query 168/193: {'domain': 'transportation', 'country': 'Switzerland'}
#   Query 168/193: Is the department/ministry of transportation in Switzerland a direct stakeholder...
#     ✓ Got structured response (1652 chars, 0 retries)
#
# Processing query 169/193: {'domain': 'transportation', 'country': 'Syrian Arab Republic'}
#   Query 169/193: Is the department/ministry of transportation in Syrian Arab Republic a direct st...
#     ✓ Got structured response (646 chars, 0 retries)
#
# Processing query 170/193: {'domain': 'transportation', 'country': 'Tajikistan'}
#   Query 170/193: Is the department/ministry of transportation in Tajikistan a direct stakeholder ...
#     ✓ Got structured response (812 chars, 0 retries)
#
# Processing query 171/193: {'domain': 'transportation', 'country': 'Thailand'}
#   Query 171/193: Is the department/ministry of transportation in Thailand a direct stakeholder (i...
#     ✓ Got structured response (1332 chars, 0 retries)
#
# Processing query 172/193: {'domain': 'transportation', 'country': 'Timor-Leste'}
#   Query 172/193: Is the department/ministry of transportation in Timor-Leste a direct stakeholder...
#     ✓ Got structured response (1323 chars, 0 retries)
#
# Processing query 173/193: {'domain': 'transportation', 'country': 'Togo'}
#   Query 173/193: Is the department/ministry of transportation in Togo a direct stakeholder (i.e.,...
#     ✓ Got structured response (1188 chars, 0 retries)
#
# Processing query 174/193: {'domain': 'transportation', 'country': 'Tonga'}
#   Query 174/193: Is the department/ministry of transportation in Tonga a direct stakeholder (i.e....
#     ✓ Got structured response (1623 chars, 0 retries)
#
# Processing query 175/193: {'domain': 'transportation', 'country': 'Trinidad and Tobago'}
#   Query 175/193: Is the department/ministry of transportation in Trinidad and Tobago a direct sta...
#     ✓ Got structured response (1183 chars, 0 retries)
#
# Processing query 176/193: {'domain': 'transportation', 'country': 'Tunisia'}
#   Query 176/193: Is the department/ministry of transportation in Tunisia a direct stakeholder (i....
#     ✓ Got structured response (1323 chars, 0 retries)
#
# Processing query 177/193: {'domain': 'transportation', 'country': 'Turkey'}
#   Query 177/193: Is the department/ministry of transportation in Turkey a direct stakeholder (i.e...
#     ✓ Got structured response (1189 chars, 0 retries)
#
# Processing query 178/193: {'domain': 'transportation', 'country': 'Turkmenistan'}
#   Query 178/193: Is the department/ministry of transportation in Turkmenistan a direct stakeholde...
#     ✓ Got structured response (1460 chars, 0 retries)
#
# Processing query 179/193: {'domain': 'transportation', 'country': 'Tuvalu'}
#   Query 179/193: Is the department/ministry of transportation in Tuvalu a direct stakeholder (i.e...
#     ✓ Got structured response (983 chars, 0 retries)
#
# Processing query 180/193: {'domain': 'transportation', 'country': 'Uganda'}
#   Query 180/193: Is the department/ministry of transportation in Uganda a direct stakeholder (i.e...
#     ✓ Got structured response (1133 chars, 0 retries)
#
# Processing query 181/193: {'domain': 'transportation', 'country': 'Ukraine'}
#   Query 181/193: Is the department/ministry of transportation in Ukraine a direct stakeholder (i....
#     ✓ Got structured response (737 chars, 0 retries)
#
# Processing query 182/193: {'domain': 'transportation', 'country': 'United Arab Emirates'}
#   Query 182/193: Is the department/ministry of transportation in United Arab Emirates a direct st...
#     ✓ Got structured response (1711 chars, 0 retries)
#
# Processing query 183/193: {'domain': 'transportation', 'country': 'United Kingdom'}
#   Query 183/193: Is the department/ministry of transportation in United Kingdom a direct stakehol...
#     ✓ Got structured response (1177 chars, 0 retries)
#
# Processing query 184/193: {'domain': 'transportation', 'country': 'United Republic of Tanzania'}
#   Query 184/193: Is the department/ministry of transportation in United Republic of Tanzania a di...
#     ✓ Got structured response (1552 chars, 0 retries)
#
# Processing query 185/193: {'domain': 'transportation', 'country': 'United States of America'}
#   Query 185/193: Is the department/ministry of transportation in United States of America a direc...
#     ✓ Got structured response (1392 chars, 0 retries)
#
# Processing query 186/193: {'domain': 'transportation', 'country': 'Uruguay'}
#   Query 186/193: Is the department/ministry of transportation in Uruguay a direct stakeholder (i....
#     ✓ Got structured response (1477 chars, 0 retries)
#
# Processing query 187/193: {'domain': 'transportation', 'country': 'Uzbekistan'}
#   Query 187/193: Is the department/ministry of transportation in Uzbekistan a direct stakeholder ...
#     ✓ Got structured response (1458 chars, 0 retries)
#
# Processing query 188/193: {'domain': 'transportation', 'country': 'Vanuatu'}
#   Query 188/193: Is the department/ministry of transportation in Vanuatu a direct stakeholder (i....
#     ✓ Got structured response (1328 chars, 0 retries)
#
# Processing query 189/193: {'domain': 'transportation', 'country': 'Venezuela, Bolivarian Republic of'}
#   Query 189/193: Is the department/ministry of transportation in Venezuela, Bolivarian Republic o...
#     ✓ Got structured response (1019 chars, 0 retries)
#
# Processing query 190/193: {'domain': 'transportation', 'country': 'Vietnam'}
#   Query 190/193: Is the department/ministry of transportation in Vietnam a direct stakeholder (i....
#     ✓ Got structured response (1104 chars, 0 retries)
#
# Processing query 191/193: {'domain': 'transportation', 'country': 'Yemen'}
#   Query 191/193: Is the department/ministry of transportation in Yemen a direct stakeholder (i.e....
#     ✓ Got structured response (1655 chars, 0 retries)
#
# Processing query 192/193: {'domain': 'transportation', 'country': 'Zambia'}
#   Query 192/193: Is the department/ministry of transportation in Zambia a direct stakeholder (i.e...
#     ✓ Got structured response (1284 chars, 0 retries)
#
# Processing query 193/193: {'domain': 'transportation', 'country': 'Zimbabwe'}
#   Query 193/193: Is the department/ministry of transportation in Zimbabwe a direct stakeholder (i...
#     ✓ Got structured response (1010 chars, 0 retries)
#
# ✓ Completed 193 queries in 1125.08 seconds
#   Average time per query: 5.83s
#
# Completed! Generated 193 assessments
# Successful parsing rate: 100.0%
#
# ✅ Assessment completed! Generated 193 assessments

# %%
# Display assessment results
num_samples = 5 if TEST_MODE else 10
display_sample_results(results, num_samples=num_samples)

# Show the structured data preview
print("\n" + "="*60)
print("STRUCTURED DATA PREVIEW")
print("="*60)
print(results[['country', 'structured_data']].head())
# Out:
# ============================================================
# SAMPLE RESULTS
# ============================================================
#
# --- Afghanistan ---
# Relevance Level: CyberRelevanceLevel.LOW
# Confidence: ConfidenceLevel.MEDIUM
# Explanation: The Ministry of Communications and Information Technology (MCIT) is identified as the primary government body responsible for Afghanistan's cybersecur...
#
# --- Albania ---
# Relevance Level: CyberRelevanceLevel.MEDIUM
# Confidence: ConfidenceLevel.MEDIUM
# Explanation: The Ministry of Infrastructure and Energy in Albania, which includes transportation responsibilities, is considered part of the critical information i...
#
# --- Algeria ---
# Relevance Level: CyberRelevanceLevel.LOW
# Confidence: ConfidenceLevel.HIGH
# Explanation: The primary responsibility for cybersecurity in Algeria lies with the Information Systems Security Agency (ASSI) under the Ministry of National Defenc...
#
# --- Andorra ---
# Relevance Level: CyberRelevanceLevel.LOW
# Confidence: ConfidenceLevel.MEDIUM
# Explanation: Available information on Andorra's government and ministries indicates that the Ministry or Department of Transportation primarily manages road infras...
#
# --- Angola ---
# Relevance Level: CyberRelevanceLevel.LOW
# Confidence: ConfidenceLevel.HIGH
# Explanation: There is no direct evidence that the Department or Ministry of Transportation in Angola is a key stakeholder in the country's national cybersecurity f...
#
# --- Antigua and Barbuda ---
# Relevance Level: CyberRelevanceLevel.LOW
# Confidence: ConfidenceLevel.MEDIUM
# Explanation: The Ministry of Transportation in Antigua and Barbuda primarily handles transportation-related matters and does not appear to be directly responsible ...
#
# --- Argentina ---
# Relevance Level: CyberRelevanceLevel.LOW
# Confidence: ConfidenceLevel.HIGH
# Explanation: The Argentine Ministry (or Department) of Transportation primarily oversees transportation infrastructure and regulation. While cybersecurity is a nat...
#
# --- Armenia ---
# Relevance Level: CyberRelevanceLevel.MEDIUM
# Confidence: ConfidenceLevel.HIGH
# Explanation: The Ministry of Transport, Communications and Information Technology — now renamed the Ministry of High-Tech Industry — was previously responsible for...
#
# --- Australia ---
# Relevance Level: CyberRelevanceLevel.HIGH
# Confidence: ConfidenceLevel.HIGH
# Explanation: The Department/Ministry of Transportation in Australia is a direct cybersecurity stakeholder as it is accountable for developing, implementing, and ma...
#
# --- Austria ---
# Relevance Level: CyberRelevanceLevel.MEDIUM
# Confidence: ConfidenceLevel.MEDIUM
# Explanation: The Austrian Cyber Security Strategy involves a Cyber Security Steering Group composed of high-ranking experts from ministries represented on Austria'...
#
# ... and 183 more countries assessed
#
# ============================================================
# STRUCTURED DATA PREVIEW
# ============================================================
#        country                                    structured_data
# 0  Afghanistan  {'relevance_level': 'CyberRelevanceLevel.LOW',...
# 1      Albania  {'relevance_level': 'CyberRelevanceLevel.MEDIU...
# 2      Algeria  {'relevance_level': 'CyberRelevanceLevel.LOW',...
# 3      Andorra  {'relevance_level': 'CyberRelevanceLevel.LOW',...
# 4       Angola  {'relevance_level': 'CyberRelevanceLevel.LOW',...

# %%
# Process and examine the results structure
processed_results = process_results(results)

def process_results(spray_output: pd.DataFrame) -> pd.DataFrame:
    """
    Process spray output to create a clean DataFrame with expanded structured data and prettified citations.
    
    Args:
        spray_output: Raw output from the sprayer
        
    Returns:
        Processed DataFrame with expanded structured data columns and prettified citations
    """
    import ast
    
    def safe_parse_citations(citations_str: str) -> List[Dict[str, Any]]:
        """Safely parse citations string from Python dictionary format."""
        if pd.isna(citations_str) or not citations_str:
            return []
        
        # If it's already a list, return it
        if isinstance(citations_str, list):
            return citations_str
        
        citations_str = str(citations_str).strip()
        
        try:
            # Use ast.literal_eval for Python dictionary strings
            return ast.literal_eval(citations_str)
        except (ValueError, SyntaxError):
            print(f"Warning: Could not parse citations: {citations_str[:100]}...")
            return []
    
    def format_citation(citation: Dict[str, Any], index: int) -> str:
        """Format a single citation into a human-readable string."""
        if not isinstance(citation, dict):
            return f"[{index}] Invalid citation format"
        
        # Extract citation information (excluding 'matched')
        url = citation.get('url', 'No URL')
        title = citation.get('title', 'No Title')
        snippet = citation.get('snippet', '')
        date = citation.get('date', '')
        last_updated = citation.get('last_updated', '')
        
        # Build formatted citation
        citation_parts = []
        
        # Add title and URL
        if title and title != 'No Title':
            citation_parts.append(f"**{title}**")
        
        if url and url != 'No URL':
            citation_parts.append(f"URL: {url}")
        
        # Add dates if available
        date_parts = []
        if date:
            date_parts.append(f"Published: {date}")
        if last_updated:
            date_parts.append(f"Updated: {last_updated}")
        if date_parts:
            citation_parts.append(" | ".join(date_parts))
        
        # Add snippet if available
        if snippet:
            # Clean up snippet (remove extra quotes, limit length)
            clean_snippet = snippet.strip().strip('"\'')
            if len(clean_snippet) > 150:
                clean_snippet = clean_snippet[:147] + "..."
            citation_parts.append(f"Snippet: {clean_snippet}")
        
        # Combine all parts
        formatted = f"[{index}] " + "\n    ".join(citation_parts)
        return formatted
    
    def prettify_citations(citations_str: str) -> str:
        """Convert citations string to prettified format."""
        citations = safe_parse_citations(citations_str)
        
        if not citations:
            return "No citations available"
        
        prettified = []
        for i, citation in enumerate(citations, 1):
            formatted_citation = format_citation(citation, i)
            prettified.append(formatted_citation)
        
        return "\n\n" + "\n\n".join(prettified)
    
    # Create a DataFrame from the processed results
    df = spray_output.copy()
    
    # Prettify enriched_citations if it exists
    if 'enriched_citations' in df.columns:
        df['enriched_citations'] = df['enriched_citations'].apply(prettify_citations)
    
    first_columns = df[['domain','country']]
    last_columns = df[['research_question', 'enriched_citations']]
    
    # Expand structured_data into separate columns if it exists
    if 'structured_data' in spray_output.columns:
        # Handle both Pydantic objects and dictionaries
        structured_series = spray_output['structured_data'].apply(
            lambda x: x.model_dump() if hasattr(x, 'model_dump') else x if isinstance(x, dict) else {}
        )
        structured_df = structured_series.apply(pd.Series)
        df = pd.concat([first_columns, structured_df, last_columns], axis=1)
    
    return df


print("Processed columns:", list(processed_results.columns))
print(f"\nProcessed data sample ({len(processed_results)} total records):")
processed_results.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Process and examine the results structure
# ----> 2 processed_results = process_results(results)
#       3 print("Processed columns:", list(processed_results.columns))
#       4 print(f"\nProcessed data sample ({len(processed_results)} total records):")
#
# File /Volumes/nibs/repos/AutoRA/usage/cyber_relevance_assessment.py:244, in process_results(spray_output)
#     242 # Prettify enriched_citations if it exists
#     243 if 'enriched_citations' in df.columns:
# --> 244     df['enriched_citations'] = df['enriched_citations'].apply(prettify_citations)
#     246 first_columns = df[['domain','country']]
#     247 last_columns = df[['research_question', 'enriched_citations']]
#
# File /Volumes/nibs/repos/AutoRA/.venv/lib/python3.13/site-packages/pandas/core/series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)   4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)   4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File /Volumes/nibs/repos/AutoRA/.venv/lib/python3.13/site-packages/pandas/core/apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File /Volumes/nibs/repos/AutoRA/.venv/lib/python3.13/site-packages/pandas/core/apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /Volumes/nibs/repos/AutoRA/.venv/lib/python3.13/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /Volumes/nibs/repos/AutoRA/.venv/lib/python3.13/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# File /Volumes/nibs/repos/AutoRA/usage/cyber_relevance_assessment.py:227, in process_results.<locals>.prettify_citations(citations_str)
#     225 def prettify_citations(citations_str: str) -> str:
#     226     """Convert citations string to prettified format."""
# --> 227     citations = safe_parse_citations(citations_str)
#     229     if not citations:
#     230         return "No citations available"
#
# File /Volumes/nibs/repos/AutoRA/usage/cyber_relevance_assessment.py:166, in process_results.<locals>.safe_parse_citations(citations_str)
#     164 def safe_parse_citations(citations_str: str) -> List[Dict[str, Any]]:
#     165     """Safely parse citations string from Python dictionary format."""
# --> 166     if pd.isna(citations_str) or not citations_str:
#     167         return []
#     169     # If it's already a list, return it
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# Save assessment results
filename_base = f"{domain}_cyber_relevance_{filename_suffix}"
save_results(results, filename_base, "output")
print(f"\n✅ Results saved as '{filename_base}'!")
# Out:
# Raw results saved to output/transportation_cyber_relevance_test.jsonl
# Processed results saved to output/transportation_cyber_relevance_test.csv
#
# ✅ Results saved as 'transportation_cyber_relevance_test'!

# %% [markdown]
# ## Results Analysis
#
# Analysis of the assessment results based on the current mode.

# %%
# Analyze results distribution
if 'relevance_level' in processed_results.columns:
    print("📊 CYBERSECURITY RELEVANCE DISTRIBUTION")
    print("="*50)
    relevance_counts = processed_results['relevance_level'].value_counts()
    print(relevance_counts)
    
    # Show percentage distribution
    relevance_pct = processed_results['relevance_level'].value_counts(normalize=True) * 100
    print("\nPercentage distribution:")
    for level, pct in relevance_pct.items():
        print(f"{level.upper()}: {pct:.1f}%")
        
# Show confidence distribution
if 'confidence' in processed_results.columns:
    print("\n📊 CONFIDENCE DISTRIBUTION")
    print("="*50)
    confidence_counts = processed_results['confidence'].value_counts()
    print(confidence_counts)
# Out:
# 📊 CYBERSECURITY RELEVANCE DISTRIBUTION
# ==================================================
# relevance_level
# CyberRelevanceLevel.LOW       2
# CyberRelevanceLevel.MEDIUM    1
# Name: count, dtype: int64
#
# Percentage distribution:
# LOW: 66.7%
# MEDIUM: 33.3%
#
# 📊 CONFIDENCE DISTRIBUTION
# ==================================================
# confidence
# ConfidenceLevel.HIGH      2
# ConfidenceLevel.MEDIUM    1
# Name: count, dtype: int64

# %%
# Show countries with HIGH cybersecurity relevance
if 'relevance_level' in processed_results.columns:
    high_relevance = processed_results[processed_results['relevance_level'] == 'high']
    print(f"\n🔥 COUNTRIES WITH HIGH CYBERSECURITY RELEVANCE ({len(high_relevance)})")
    print("="*60)
    
    if len(high_relevance) > 0:
        for _, row in high_relevance.iterrows():
            print(f"• {row['country']} (Confidence: {row.get('confidence', 'N/A')})")
            if 'explanation' in row and row['explanation']:
                explanation = row['explanation'][:100] + "..." if len(row['explanation']) > 100 else row['explanation']
                print(f"  └─ {explanation}")
            print()
    else:
        print("No countries with HIGH relevance found in this assessment.")
        
    # Show medium relevance too if in test mode
    if TEST_MODE:
        medium_relevance = processed_results[processed_results['relevance_level'] == 'medium']
        if len(medium_relevance) > 0:
            print(f"\n📊 COUNTRIES WITH MEDIUM CYBERSECURITY RELEVANCE ({len(medium_relevance)})")
            print("="*60)
            for _, row in medium_relevance.iterrows():
                print(f"• {row['country']} (Confidence: {row.get('confidence', 'N/A')})")
else:
    print("No relevance level data found to analyze.")
# Out:
# 🔥 COUNTRIES WITH HIGH CYBERSECURITY RELEVANCE (0)
# ============================================================
# No countries with HIGH relevance found in this assessment.
#
# 📊 COUNTRIES WITH MEDIUM CYBERSECURITY RELEVANCE (1)
# ============================================================
# • Albania (Confidence: ConfidenceLevel.HIGH)

# %%
# # Show countries with HIGH cybersecurity relevance (uncomment if you ran the full assessment)
# if 'processed_full' in locals() and 'relevance_level' in processed_full.columns:
#     high_relevance = processed_full[processed_full['relevance_level'] == 'high']
#     print(f"\n🔥 COUNTRIES WITH HIGH CYBERSECURITY RELEVANCE ({len(high_relevance)})")
#     print("="*60)
#     for _, row in high_relevance.iterrows():
#         print(f"• {row['country']} (Confidence: {row.get('confidence', 'N/A')})")
#         if 'explanation' in row and row['explanation']:
#             explanation = row['explanation'][:100] + "..." if len(row['explanation']) > 100 else row['explanation']
#             print(f"  └─ {explanation}")
#         print()

# %% [markdown]
# ## Configuration & Usage
#
# ### Switching Between Test and Full Mode
#
# **Test Mode** (`TEST_MODE = True`):
# - Runs on first 5 countries only
# - Quick validation of setup and functionality
# - Generates `ministry_ministry_cyber_test.*` output files
#
# **Full Mode** (`TEST_MODE = False`):
# - Runs on all 193 countries
# - Takes 3-4 minutes to complete
# - Generates `ministry_ministry_cyber_full_assessment.*` output files
#
# ### Key Features
#
# 1. **✅ Script Integration**: Uses the `cyber_relevance_assessment.py` script as an importable module
# 2. **✅ Dataset Loading**: Loads the ministry ministries dataset with 193 countries
# 3. **✅ Structured Assessment**: Uses Pydantic models for reliable data extraction
# 4. **✅ Unified Code**: Same assessment code for both test and full modes, controlled by `max_queries`
# 5. **✅ Results Processing**: Expands structured data into analyzable columns
# 6. **✅ Multiple Output Formats**: Saves results in JSON, JSONL, and CSV formats
#
# ### Key Columns Extracted:
# - `country`: Country name
# - `domain`: Ministry domain ("ministry")
# - `research_question`: The assessment question asked
# - `enriched_citations`: Citations with metadata
# - `relevance_level`: HIGH/MEDIUM/LOW/NONE cybersecurity involvement
# - `confidence`: Assessment confidence level
# - `explanation`: Detailed explanation with citations
#
# ### To Run Full Assessment:
# 1. Change `TEST_MODE = False` in the second cell
# 2. Run all cells - the same code will automatically handle the full dataset
